# %%
import cv2
from ultralytics import YOLO

# %%
# Load the trained YOLOv8 model
model = YOLO('runs/detect/train4/weights/best.pt')

# Open a connection to the webcam (use 0 for the default camera, or the appropriate index for other cameras)

# %%
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # Check if frame is read correctly
    if not ret:
        print("Error: Could not read frame.")
        break
    
    # Perform inference on the frame
    results = model(frame)
    
    # Visualize the results
    annotated_frame = results[0].plot()  # Annotate the frame with predictions
    
    # Display the resulting frame
    cv2.imshow('YOLOv8 Real-Time Inference', annotated_frame)
    
    # Break the loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 27.0ms
# Speed: 3.8ms preprocess, 27.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.1ms
# Speed: 2.8ms preprocess, 25.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.1ms
# Speed: 2.4ms preprocess, 25.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 2.4ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.5ms
# Speed: 2.3ms preprocess, 24.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.2ms
# Speed: 3.3ms preprocess, 24.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# QObject::moveToThread: Current thread (0x134d64c0) is not the object's thread (0x136d4ae0).
# Cannot move to target thread (0x134d64c0)
#
# ...
